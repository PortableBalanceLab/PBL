# %% [markdown]
# # `S0`: Sensor Lab 0: Set Up the Raspberry Pi
#
# In this session, we will get you set up with your Raspberry Pi. By the end of this part, you should have:
#
# - Joined the same WiFi network as your Pi
# - Connected to your Pi via Virtual Network Computing (VNC)
# - Explored the Raspberry Pi's Desktop environment
# - Know what the python editor, terminal (shell), and programs are
# - Know how to run a Python program via the terminal
#
# __Outline:__
#
# * [1. Join the Same WiFi Network as the Pi](#join-wifi-network)
#   * [1.1 Figure Out Your Laptop's MAC Address](#find-mac-address)
#   * [1.2 Get a `TUD-facility` WiFi License Barcode](#get-wifi-license)
#   * [1.3 Use the License Barcode to Register Your Laptop with `TUD-facility`](#register-laptop-wifi)
#   * [1.4 Join the `TUD-facility` WiFi Network on Your Laptop](#join-tud-facility)
# * [2. Connect to the Pi](#connect-to-pi)
#   * [2.1 Figure out your Pi's IP Address](#find-pi-ip-address)
#   * [2.2 Connect to the Pi Using VNC Connect](#connect-to-pi-vnc)
# * [3. Configure the Pi via VNC](#configure-pi)
# * [4. Explore the Raspberry Pi Desktop Environment](#explore-pi)
#   * [4.1 The Command Line](#explore-cmdline)
#   * [4.2 Navigating With the Terminal](#navigating-terminal)
#   * [4.4 MU & Thonny](#mu-and-thonny)
#   * [4.5 Python Shell](#python-shell)
#   * [4.6 Python Editor](#python-editor)
#   * [4.7 Running Python Program from the Terminal](#run-python-from-terminal)

# %% [markdown]
# ## 1. Join the Same WiFi Network as the Pi <a id="join-wifi-network" />
#
# A monitor, mouse, and keyboard may be used to control your Raspberry Pi. However, in this course, we use a remote VNC connection to the Pi. VNC is necessary because it enables multiple computers to connect to the Pi simultaneously (handy for group work) and it lets you connect to the Pi while it's strapped to a test subject without a mess of wires.
#
# > Are you working on a pose estimation sensor (`S1`)?
# >
# > The camera module doesn't work via VNC, so you will mostly be physically connecting a monitor, mouse, and keyboard to your Pi. However, it's still valuable to setup VNC for the parts of the lab/development where you aren't using the camera.
#
# Connecting to a Pi requires being on the same WiFi network as it. All Pis are registered to the `TUD-facility` WiFi network before the course begins. **Therefore, the only way to connect to your Pi from your laptop is for your laptop to also join the `TUD-facility` WiFi network, which we describe here.**
#
#
# ### 1.1 Figure Out Your Laptop's MAC Address  <a id="find-mac-address" />
#
# Joining `TUD-facility` requires that your laptop's [MAC address](https://en.wikipedia.org/wiki/MAC_address) is pre-registered with `TUD-facility`. You **must** find out your device's (laptop's) WiFi networking card's MAC address.
#
# [This](https://itssc.rpi.edu/hc/en-us/articles/360001995831-How-to-find-your-MAC-Address-for-MacOS-Linux-Windows#:~:text=MacOS%2FLinux%20To%20locate%20the%20MAC%20Address%20on%20MacOS%2C,your%20IP%20address%20as%20well%20your%20MAC%20address) guide explains how to find your MAC address on MacOS, Linux, or Windows. Googling "Mac/Windows/Linux find wifi adapter MAC address", or using an LLM, will show you other options.
#
# Here are some important things to keep in mind:
#
# - **On Windows**:
#
#   - Almost all guides describe running `ipconfig /all` in the command line.
#   - However, **beware**: many laptops have multiple network adaptors. The adaptor you register with `TUD-facility` **must** be your laptop's WiFi adapter. Different laptop brands use different adaptor names, but most laptop brands in The Netherlands use an Intel WiFi adaptor, usually with a name like `Intel(R) Wi-Fi 6E AX210` (for example).
#   - **Beware of MAC address randomization**: some modern Windows laptops enable MAC address randomization for privacy, which is incompatible with `TUD-Facility`. Search online/AI to figure out if your laptop has it enabled.
#
# - **On Mac**:
#
#   - Guides usually describe either navigating the system settings to find the MAC address or running `networksetup -listallhardwareports` / `ifconfig` in the command line.
#   - **Beware of MAC address randomization**: Modern Apple laptops have a "private WiFi network" setting, which randomizes your MAC address whenever you connect to a network. This is incompatible with `TUD-Facility`. Search online/AI to figure out if your laptop has it enabled.
#
# - **On Linux**:
#
#   - Almost all guides describe running `ip link` in the command line. Most linux distributions name the WiFi adaptor `wlan0` or similar.
#   - **Beware of MAC address randomization**. Whether it's enabled or not strongly depends on your laptop manufacturer (if Linux is pre-packaged with the laptop) and Linux distribution. MAC address randomization is incompatible with `TUD-Facility`. Search online/AI to figure out if it's enabled/disabled on your laptop.
#
# > ❗**Important**: By the end of this step, you should have a MAC address for your WiFi adapter that looks like: `1C-81-9F-53-91-22` or `1c:81:9f:53:91:22`.
# >
# > The `TUD-facility` registration website **requires** this address in order to register your device with the network. The website usually uses the colon (i.e. not-Windows) format when it displays MAC addresses (e.g. `1c:81:9f:53:91:22`).
#
#
# ### 1.2 Get a `TUD-facility` WiFi License Barcode  <a id="get-wifi-license" />
#
# You need a license to join `TUD-facility`. The license is distributed as a QR code that the course organizers place in each Raspberry Pi's box. If a QR code is missing or damaged, spares can be generated upon request.
#
# The QR-code should look something like this:
#
# ![Example 2D Barcode](images/example_qrcode.png)
#
# Your QR-code will be linked to one NETID account and will let that person register up to 3 devices' MAC addresses with the `TUD-facility` WiFi network. If you have fewer QR codes than people in your team, the person who uses the QR code should register a teammate's device.
#
#
# ### 1.3 Use the License Barcode to Register Your Laptop with `TUD-facility`  <a id="register-laptop-wifi" />
#
# You will use your license to register your device with the `TUD-facility` WiFi, which will give you a password (`iPSK`) that you can use to login to the network from your laptop.
#
# - Scan the QR-code with your phone
# - Open the web link
#   - **Note**: the link only works if you are on `eduroam`, or the TU Delft VPN (EduVPN). The website should look like this:
#
# <img src="images/TUD-Facility_LoginScreen.png" width="400px" />
#
# - Login to the system with your netID. The website should then look like this:
#
# <img src="images/TUD-Facility_ClaimLicense.png" width="400px" />
#
# - Click `Claim this License` to claim the license against your netID and close this window.
# - Goto https://infra.tudelft.net/virtualnetwork (with a laptop) and login with your netID. Once logged in, it will look like this:
#
# <img src="images/TUD-Facility_Splash.png" width="500px" />
#
# - Then select your claimed license:
#
# <img src="images/TUD-Facility_LicenseSelected.png" width="500px" />
#
# - Then go to `License Devices`. In that UI, You can see here all the deviecs within the lab. You can filter the view to limit the number of devices. It should look like this:
#
# <img src="images/TUD-Facility_SelectDevices.png" width="500px" />
#
# - Click `Add Device` and fill out your laptops' details:
#
#   - Fill in the MAC address field with your laptop's MAC address.
#   - Fill in a relevant `Device name` and `Description` by clicking on the `-` behind the name. The name/description should try to identify who you are and what device it is, so that network adminstrators can more easily diagnose any connection issues with your device.
#   - **Select `Wireless` as the connection type (IMPORTANT)**.
#   - Click on the `-` behind the iPSK button and then `Generate PSK` to generate a unique WiFi password for that laptop. **This is the password you shall use to connect to `TUD-Facility`
#   - Finally, click `Add Device`
#   - Repeat this process for all laptops you wish to register.
#
# After registering a device, you should be able to look up your laptop in the `License Devices` screen. You can use that screen to see your registration and PSK code if you later forget it. Once your device(s) are registered, they should be able to join the `TUD-Facility` WiFi network and connect to your Pi.
#
# ### 1.4 Join the `TUD-facility` WiFi Network on Your Laptop  <a id="join-tud-facility" />
#
# 1. Using your laptop's WiFi networking UI, change your WiFi network from whatever it currently is (probably, `eduroam`) to `TUD-facility`.
# 2. When prompted for a password, use the `iPSK` you received after registering your device on the network.
# 3. Your laptop should successfully connect to the network and have internet access
#
#
# ## 2. Connect to the Pi  <a id="connect-to-pi" />
#
# Now that you are on the same WiFi network as the Pi, you can connect to it. To do this, you first need to figure out the Pi's IP address. You will then use the IP address to connect to the Pi with an appropriate VNC client.
#
#
# ### 2.1 Figure out your Pi's IP Address  <a id="find-pi-ip-address" />
#
# Before you were given the Pi, the course organizers registered it on the `TUD-facility` network beforehand. The network then gave the Pi an IP address, which is what you need.
#
# A list of all IP addresses for all PBL Pis on the `TUD-facility` virtual network web portal (https://infra.tudelft.net/virtualnetwork). The procedure for finding out your Pi's address is as follows
#
# - Power up your Raspberry Pi (so that it connects to the network)
# - Open and login to the network portal: https://infra.tudelft.net/virtualnetwork
# - Use the `License Devices` list to find your Pi. Your Pi's name is `pblhostX`, where `X` is your box's letter (e.g. if your box has an `A` on it, your Pi will be listed as `pblhosta`.
# - The PI address of your Pi should be listed in the user interface. It should look something like `192.168.7.4` (different number).
# - If you cannot see an IP address below the Pi, then the Pi may not be powered on, or it ma not have sucessfully connected to `TUD-facility` - ask for help if this is the case. In most cases, fixing the Pi involves physically plugging in a monitor+keyboard+mouse and ensuring the Pi is connected to `TUD-Facility`.
#
# > ❗**Important**: By the end of this step, you should have your Pi's IP address, which should look like: `192.168.7.4`
#
# ---
#
# > ℹ️ **Having Trouble Figuring out Your Pi's IP Address?**
# >
# > We may be able to help find the IP address for you. For example, by checking the `TUD-facility` web portal from our admin accounts. It can also be the case that your device was incorrectly pre-configured with the network, but we can also help with that.
#
# ### 2.2 Connect to the Pi Using VNC Connect  <a id="connect-to-pi-vnc" />
#
# To access the Raspberry Pi from your machine, you need to install `VNC connect`, a VNC client. The installer and manual can be found here:
#
# - https://www.realvnc.com/en/connect/download/viewer/
#
# **Note**: you can open VNC viewer without logging in (no account needed). Check the lower part of the window.
#
# 1. Once installed, start up the `VNC viewer` on your machine. Type in the IP address on the top of the the VNC viewer.
#
# ![VNC viewer](images/Capture_VNCviewerownmachine.png)
#
#
#
#
# 2. When asked for login credentials, you need to use your Raspberry Pi’s credentials. Before you were given the Pi, the PBL organizers flashed each Pi with a user account of `pbl` and a semi-random password. **You should have been supplied with this password on a piece of paper, if you don't have it, ask an organizer**.
#
# 3. You should now see your Raspberry Pi desktop within the VNC viewer. This means you no longer need the screen, mouse and keyboard to work on your Raspberry Pi.

# %% [markdown]
# ## 4. Explore the Raspberry Pi Desktop Environment <a id="explore-pi" />
#
# Now that we are connected to the machine via VNC, let's do some exploring.
#
# ### 4.1 The Command Line  <a id="explore-cmdline" />
#
# If you are a Windows or Mac user, you may have never used the command line. If you are a Linux user, on the other hand, you almost certainly will have done so. Although it is possible to use a Linux system completely via the graphical interface, in general you will need to type commands into the command line. You do this to install new applications and to configure the Raspberry Pi.
#
# To open the terminal, click on the `Terminal` icon (on the top of your Pi's desktop - it looks like a monitor with a blank screen).
#
#
# ### 4.2 Navigating With the Terminal  <a id="navigating-terminal" />
#
# You will find yourself using three commands a lot when you are using the command line. The first command is `pwd`, which is short for `p`rint `w`orking `d`irectory. It prints which directory you are currently in. You can run `pwd` by typing it after the `$` sign in the terminal window:
#
# ```bash
# $ pwd
# /home/pbl  # the output from `pwd`
# ```
#
# Another common command is `ls`, which is short for list. It prints a list of files and directories within the working directory. Try the following:
#
# ```bash
# $ ls
# ```

# %% [markdown]
# ![Terminal commands](images/Capture_RP_pwd_ls.png)
#
# The final command we are going to cover is `cd`, which is short for `c`hange `d`irectory. `cd` is used to naviagate the filesytem by changing the current directory (the thing printed by `pwd`). It can change the directory relative either to the old working directory or to a completely different directory if you specify the whole directory, starting with /.
#
# For example, the following command will change the current working directory to `/home/pbl/Desktop`:
#
# ```bash
# $ pwd
# /home/pbl
# $ cd Desktop
# $ pwd
# /home/pbl/Desktop
# ```
#
# You could do the same thing by using an *absolute* path:
#
# ```bash
# $ cd /home/pbl/Desktop
# $ pwd
# /home/pbl/Desktop
# ```
#
# Or by navigating to `~`, which is shorthand for "home directory":
#
# ```bash
# $ cd ~
# $ pwd
# /home/pbl
# $ cd ~/Desktop
# $ pwd
# /home/pbl/Desktop
# ```

# %% [markdown]
# Note that when entering a directory or filename, you do not have to type all of it. Instead, at any time after you have typed some of the name, you can press the TAB key. If the filename is unique at that point, it will be automatically completed for you.

# %% [markdown]
# ### 4.4 MU & Thonny  <a id="mu-and-thonny" />
#
# On the RP there are several Python editors. We recommend either Thonny or Mu.
#
# 1. Open the program on your Rasbpetty Pi via `Menu` (raspberry icon, top-left) -> `Programming` -> `Mu` or `Thonny`
#
#
# > ⚠️ **Note**: If the program doesn't show up in your menu you first need to download and install it. To do this follow the steps on this website: https://codewith.mu/en/howto/1.0/install_raspberry_pi (or use an alternative editor).
#
#
#  ![Terminal commands](images/Capture_MU_select_pyhton3.png)

# %% [markdown]
# ### 4.5 Python Shell  <a id="python-shell" />
#
# Since you might be fairly new to Python, it's helpful to interactively type in Python commands and see what this does. Click on the REPL icon at the top of the `Mu` window. The window will split opening up an area at the borrom of the screen where you can type commands (similar to what we know in Matlab). This area is called REPL for Read-Evaluate-Print-Loop.
#
#
# ### 4.6 Python Editor  <a id="python-editor" />
#
# The REPL is a great place to experiment, but not the right place to write a program. Python programs are saved in files, so that you do nothave to retype all the commands seperately.The editor area is where you can either write code for a new program, or open an existing python program. Let's run a very simple example.
#
# 1. Create a python program that prints `Hello` and then `World` in Mu:
#
# ```python
# # create a new python file and write this:
#
# print('Hello')
# print('World')
# ```
#
# 2. Save this as a Python program called `hello.py`. If you do not change the directory, it will be saved in the folder `/home/pbl/mu_code`
#
# 3. Now that you have saved it, you can run the program in Mu using the `Run` button. The result will be shown in the Python Shell
#
#
# ### 4.7 Running Python Program from the Terminal <a id="run-python-from-terminal" />
#
# An already saved python program does not necessarily need to be run via an editor. Another way of running a Python shell is to use the Terminal. To run your `hello.py` program, first navigate to the right directory in the terminal:
#
# ```bash
# cd /home/pbl/mu_code/
# ```
#
# Then tell it run the program using python3:
#
# ```bash
# python3 hello.py
# ```
